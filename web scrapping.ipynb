# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

def extract_course_data(url):
    response = requests.get(url)
    content = response.content
    soup = BeautifulSoup(content, 'html.parser')
    
    # Extracting the course link
    link = url

    # Extracting the title
    h1_tags = soup.find_all('h1')
    title = [tag.get_text(strip=True) for tag in h1_tags]

    # Extracting the description
    div_tags = soup.find_all(class_='desc_less')
    description = ' '.join(para.find('p').text.strip() for para in div_tags if para.find('p'))

    # Extracting the duration
    dur=soup.find_all(class_='duration-of-course')
    duration=[]
    for i in dur:
        res=i.find_all('p')
        text=res[0].get_text(strip=True)
        duration.append(text)
    duration_text = ' | '.join(duration) if duration else None

   #Course Start date
    dur=soup.find_all(class_='duration-of-course')
    start=[]
    for i in dur:
        res=i.find_all('p')
        text=res[2].get_text(strip=True)
        start.append(text) 
    duration_text1 = ' | '.join(start) if duration else None

                
    # Print debug information

    
    # Extracting unique items for "What you will learn"
    learn = soup.find_all(class_='pl-deeper-undstnd to_flex_ul')
    unique_items = set()
    for item in learn:
        ul = item.find('ul')
        if ul:
            li_tags = ul.find_all('li')
            for li in li_tags:
                item_text = li.get_text(strip=True)
                if item_text:
                    unique_items.add(item_text)
    what_you_will_learn = ' | '.join(sorted(unique_items))

    # Extracting fee details
    fees = soup.find_all(class_='program-details-total-pay-amt-right')
    inr_fee = None
    usd_fee = None
    for div in fees:
        text = div.get_text(separator=' ', strip=True)
        if 'Due by:' in text:
            text = text.split('Due by:')[0].strip()
        text = ' '.join(text.split())
        if 'INR' in text:
            inr_fee = text
        elif 'USD' in text:
            usd_fee = text

    # Extracting the target audience
    target_tags = soup.find_all('h4', class_='cs-titlec')
    targets = [tag.get_text(strip=True) for tag in target_tags]
    target_audience = ' | '.join(targets) if targets else None

    # Extracting skills
    skills = soup.find_all(class_='key-skills-sec')
    skills_tag = []
    for skill in skills:
        ul = skill.find('ul')
        if ul:
            li_tags = ul.find_all('li')
            for li in li_tags:
                item_text = li.get_text(strip=True)
                if item_text:
                    skills_tag.append(item_text)
    formatted_skills = ' | '.join(sorted(skills_tag))

    # Extracting institute name
    institute_tags = soup.find_all('h4', class_='about-ititle')
    institute = [tag.get_text(strip=True) for tag in institute_tags]

    # Extracting prerequisites or experience
    experience = soup.find_all(class_='eligible-right-top-list')
    Working = [exp.get_text(strip=True) for exp in experience]

    # Extracting content
    glances = soup.find_all(class_='sylab-tab-ul')
    formatted_items = []
    for glance in glances:
        items = glance.get_text(strip=True).split('\n')
        for item in items:
            if item.strip():
                formatted_items.append(item.strip())
    content_text = ' | '.join(formatted_items)

    # Creating a dictionary with extracted data
    data = {
        'Course Link': link,
        'Title': title[0] if title else None,
        'Description': description,
        'Duration': duration_text,
        'Course Start':duration_text1,
        'What you will learn': what_you_will_learn,
        'INR Fee': inr_fee,
        'USD Fee': usd_fee,
        'Target Audience': target_audience,
        'Skills': formatted_skills,
        'Institute': ' | '.join(institute),
        'Prerequisites/Eligibility criteria': ' | '.join(Working),
        'Content': content_text
    }
    
    return data

# List of URLs to process
urls = [
    'https://talentedge.com/golden-gate-university/doctor-of-business-administration',
    'https://talentedge.com/iim-kozhikode/professional-certificate-programme-in-hr-management-and-analytics',
    'https://talentedge.com/opjindal-global-business-school/masters-of-business-administration-opj-global-university',
    'https://talentedge.com/iim-raipur/executive-certificate-program-in-general-management',
    'https://talentedge.com/iim-kozhikode/applied-financial-risk-management-course',
    'https://talentedge.com/goa-institute-of-management/exectuive-pg-program-in-health-care-management',
    'https://talentedge.com/iim-raipur/certificate-course-machine-learning-for-managers',
    'https://talentedge.com/iim-raipur/certificate-course-strategic-management',
    'https://talentedge.com/iiit-allahabad/big-data-analytics-machine-learning-course-iiit-allahabad',
    'https://talentedge.com/iit-delhi/certificate-programme-in-5g-iot-ai'
]

# Extract data for each URL and store it in a list
data_list = [extract_course_data(url) for url in urls]

# Create a DataFrame from the collected data
df = pd.DataFrame(data_list)

# Print the DataFrame
df
# Out:
#                                          Course Link  \
# 0  https://talentedge.com/golden-gate-university/...
# 1  https://talentedge.com/iim-kozhikode/professio...
# 2  https://talentedge.com/opjindal-global-busines...
# 3  https://talentedge.com/iim-raipur/executive-ce...
# 4  https://talentedge.com/iim-kozhikode/applied-f...
# 5  https://talentedge.com/goa-institute-of-manage...
# 6  https://talentedge.com/iim-raipur/certificate-...
# 7  https://talentedge.com/iim-raipur/certificate-...
# 8  https://talentedge.com/iiit-allahabad/big-data...
# 9  https://talentedge.com/iit-delhi/certificate-p...
#
#                                                Title  \
# 0                  Doctor Of Business Administration
# 1  Professional Certificate ProgrammeIn HR Manage...
# 2                 Masters Of Business Administration
# 3  Executive Certificate ProgramIn General Manage...
# 4  Professional Certificate ProgramIn Applied Fin...
# 5  Executive Post Graduate ProgramIn Health Care ...
# 6  Executive Certificate ProgramIn Machine Learni...
# 7  Executive Development ProgramIn Advanced Strat...
# 8  PG Certificate ProgramIn Machine Learning And ...
# 9  Certificate Programme In 5G And Its Applicatio...
#
#                                          Description             Duration  \
# 0  Go beyond the boundaries of your job, without ...  Duration: 36 Months
# 1  This program deals with the collection and man...   Duration: 5 Months
# 2  This program is a one year online MBA designed...  Duration: 12 months
# 3  Gain in-depth understanding of every aspect of...                 None
# 4  Gain the Foresight and Expertise to Identify a...                 None
# 5  India's healthcare industry is expected to gro...  Duration: 11 months
# 6     “Machine Learning is the new SQL for Big Data"                 None
# 7  Unveil the most powerful strategies, and be on...                 None
# 8  Organizations today operate in a world surroun...                 None
# 9  With the onset of 5G, the dawn of overwhelming...                 None
#
#    Course Start                                What you will learn  \
# 0  15 Feb, 2024  Data collection techniques | Disruptive Innova...
# 1  15 Feb, 2024  92% Satisfaction Score | 95% Completition Rate...
# 2  31 Mar, 2024  78% Referability | 92% Satisfaction score | 95...
# 3          None  78% Referability | 92% Satisfaction score | 95...
# 4          None  78% Referability | 92% Satisfaction score | 95...
# 5  31 Mar, 2024  78% Referablity | 92% Satisfaction Score | 95%...
# 6          None  78% Referablity | 92% Satisfaction Score | 95%...
# 7          None  78% Referablity | 92% Satisfaction Score | 95%...
# 8          None  78% Referablity | 92% Satisfaction Score | 95%...
# 9          None  1G to 5G evolution | 5G's impact on Emerging T...
#
#              INR Fee    USD Fee  \
# 0  INR 1226438 + GST  USD 15000
# 1   INR 105932 + GST   USD 1287
# 2   INR 127119 + GST      USD 0
# 3   INR 160000 + GST   USD 3200
# 4   INR 100000 + GST   USD 2000
# 5    INR 97458 + GST   USD 1189
# 6    INR 75000 + GST   USD 1700
# 7   INR 180000 + GST   USD 3800
# 8   INR 200000 + GST   USD 4000
# 9   INR 100000 + GST   USD 2000
#
#                                      Target Audience  \
# 0  Working professionals who are looking for a tr...
# 1  Managers/ HR Professionals who need to take cr...
# 2  This programme is useful for freshers as well ...
# 3  Functional Managers, Entrepreneurs, Business H...
# 4  Working Professionals, Finance Professionals, ...
# 5  Freshers, Early-age Professionals, Medical Pro...
# 6  Business Managers & Department Heads, Business...
# 7  Leaders, Managers  & Function Heads, Executive...
# 8                                               None
# 9  Communication Engineers, Technical Heads, Youn...
#
#                                               Skills  \
# 0  Applied Research | Concept Selection | Critica...
# 1  Development Analytics | Employee retention, | ...
# 2  Analytical Thinking | Decision Making in busin...
# 3  Analytical | Communication | Decision-Making |...
# 4  Decision-making | Financial risk management | ...
# 5  Benchmarking in Healthcare | Ethical & Legal i...
# 6  Data Visualization & Forecasting | Decision Mo...
# 7  Decision-making | Strategic management | Strat...
# 8  Data Manipulation | Data Visualization | Linea...
# 9    Data Analytics | Networking | Programming skill
#
#                               Institute  \
# 0                Golden Gate University
# 1                IIM Kozhikode | upGrad
# 2       OPJindal Global Business School
# 3                            IIM Raipur
# 4                         IIM Kozhikode
# 5  Goa Institute of Management | upGrad
# 6                            IIM Raipur
# 7                            IIM Raipur
# 8                  CSTCP-IIIT Allahabad
# 9                             IIT Delhi
#
#                   Prerequisites/Eligibility criteria  \
# 0  Master's Degree (or equivalent) or Bachelors D...
# 1  - Minimum 2 years work experience if you have ...
# 2  Candidates must hold a graduation degree in an...
# 3  For Indian Participants – Graduates (10+2+3) o...
# 4  For Indian Participants – Graduates (10+2+3) f...
# 5  Professionals/freshers holding any bachelor’s ...
# 6  For Indian Participants – Graduates (10+2+3) o...
# 7  For Indian Participants – Graduates (10+2+3) o...
# 8  For Indian Participants – Graduates (10+2+3) f...
# 9  For Indian Participants – B.Tech, B.E, BCA or ...
#
#                                              Content
# 0  Foundation (12 Credits)Concentration (12 Credi...
# 1  Introduction to HR AnalyticsHR Practices and B...
# 2  The Firm and the ConsumerGlobal EconomicsBusin...
# 3  Management and Business EconomicsData Analytic...
# 4  BasicsFinancial Instruments and Their MarketsM...
# 5  Program IntroductionFundamentals of Management...
# 6                   Foundation ModuleAdvanced Module
# 7  Understanding Role of Strategy in BusinessWhy ...
# 8  MODULE 1 - FUNDAMENTALS OF PYTHON (By Industry...
# 9  Basics of CommunicationsUnderlying Technologie...

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in d:\imp\anaconda3\lib\site-packages (3.1.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: et-xmlfile in d:\imp\anaconda3\lib\site-packages (from openpyxl) (1.1.0)

# %%
excel_file_path = 'course_data.xlsx'
df.to_excel(excel_file_path, index=False, engine='openpyxl')

# %%
print(f"Data saved to {excel_file_path}")
# Out:
# Data saved to course_data.xlsx
